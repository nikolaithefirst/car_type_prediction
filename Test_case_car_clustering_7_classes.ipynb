# %% [markdown]
# ## Работа над тестовым заданием по классификации типа кузова автомобиля
#
# Работа проводилась по следующим пунктам:
# 1. Анализ входных данных из датасета.
# 2. Фильтрация данных.
# 3. Преобразование переменных.
# 4. Классификация моделей авто по типу кузова.
#
# Далее в ноутбуке оставил комментарии, которые минимально объясняют мою логику действий.

# %% [markdown]
# ### 1. Анализ входных данных из датасета
#
# Импортируем необходимые библиотеки.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier

# %% [markdown]
# ### Сначала нужно указать путь к файлу

# %%
df = pd.read_csv('C:/users/Nikolai/notebooks/Test_problem/auto_complectations.csv')

# %% [markdown]
# Проверяем содержание датасета

# %%
df.head()
# Out:
#   brand     model               complect        type_car  seats  doors  \
# 0  Audi  A3 Sedan          1.4 TFSI 7AMT  Седан класса C      5      4
# 1  Audi  A3 Sedan    sport 1.4 TFSI 7AMT  Седан класса C      5      4
# 2  Audi  A3 Sedan          2.0 TFSI 7AMT  Седан класса C      5      4
# 3  Audi  A3 Sedan  2.0 TFSI 7AMT quattro  Седан класса C      5      4
# 4  Audi  A3 Sedan    sport 2.0 TFSI 7AMT  Седан класса C      5      4
#
#                Двигатель   Мощность Крутящий момент двигателя  \
# 0  бензиновый (1395 см³)  150 л. с.                   250 Н·м
# 1  бензиновый (1395 см³)  150 л. с.                   250 Н·м
# 2  бензиновый (1984 см³)  190 л. с.                   320 Н·м
# 3  бензиновый (1984 см³)  190 л. с.                   320 Н·м
# 4  бензиновый (1984 см³)  190 л. с.                   320 Н·м
#
#                  Коробка передач  ... Разгон до сотни Максимальная скорость  \
# 0  роботизированная (7 ступеней)  ...     8.2 секунды              224 км/ч
# 1  роботизированная (7 ступеней)  ...     8.2 секунды              224 км/ч
# 2  роботизированная (7 ступеней)  ...     6.8 секунды              250 км/ч
# 3  роботизированная (7 ступеней)  ...     6.2 секунды              242 км/ч
# 4  роботизированная (7 ступеней)  ...     6.8 секунды              242 км/ч
#
#   Расход топлива (л/100 км)\nгород / трасса / смешанный Дорожный просвет  \
# 0                                    5.9 / 4.1 / 4.8              165 мм
# 1                                    5.9 / 4.1 / 4.8              165 мм
# 2                                    7.2 / 4.7 / 5.6              165 мм
# 3                                    7.2 / 4.8 / 5.7              165 мм
# 4                                    7.2 / 4.7 / 5.6              165 мм
#
#   Габариты (длина × ширина × высота) Колёсная база Объём багажника  \
# 0                 4458 × 1796 × 1416       2637 мм           425 л
# 1                 4458 × 1796 × 1416       2637 мм           425 л
# 2                 4458 × 1796 × 1416       2637 мм           425 л
# 3                 4458 × 1796 × 1416       2637 мм           390 л
# 4                 4458 × 1796 × 1416       2637 мм           425 л
#
#   Объём багажника максимальный Объём топливного бака Масса автомобиля
# 0                        880 л                  50 л          1320 кг
# 1                        880 л                  50 л          1320 кг
# 2                        880 л                  50 л          1395 кг
# 3                        845 л                  55 л          1465 кг
# 4                        880 л                  50 л          1395 кг
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#       brand model              complect           type_car  seats  doors  \
# 1698  Volvo  XC90     D5 AT 5S R-Design  Большой кроссовер      5      5
# 1699  Volvo  XC90     T6 AT 7S R-Design  Большой кроссовер      7      5
# 1700  Volvo  XC90     D5 AT 7S R-Design  Большой кроссовер      7      5
# 1701  Volvo  XC90  T8 AT 7S Inscription  Большой кроссовер      7      5
# 1702  Volvo  XC90     T8 AT 7S R-Design  Большой кроссовер      7      5
#
#                   Двигатель   Мощность Крутящий момент двигателя  \
# 1698   дизельный (1969 см³)  235 л. с.                   480 Н·м
# 1699  бензиновый (1969 см³)  320 л. с.                   400 Н·м
# 1700   дизельный (1969 см³)  235 л. с.                   480 Н·м
# 1701   гибридный (1969 см³)  407 л. с.                   640 Н·м
# 1702   гибридный (1969 см³)  407 л. с.                   640 Н·м
#
#                   Коробка передач  ... Разгон до сотни Максимальная скорость  \
# 1698  автоматическая (8 ступеней)  ...     7.8 секунды              220 км/ч
# 1699  автоматическая (8 ступеней)  ...     6.5 секунды              230 км/ч
# 1700  автоматическая (8 ступеней)  ...     7.8 секунды              220 км/ч
# 1701  автоматическая (8 ступеней)  ...     5.6 секунды              230 км/ч
# 1702  автоматическая (8 ступеней)  ...     5.6 секунды              230 км/ч
#
#      Расход топлива (л/100 км)\nгород / трасса / смешанный Дорожный просвет  \
# 1698                                    6.4 / 5.5 / 5.8              237 мм
# 1699                                        0 / 0 / 8.3              237 мм
# 1700                                    6.4 / 5.5 / 5.8              237 мм
# 1701                                        0 / 0 / 2.1              237 мм
# 1702                                        0 / 0 / 2.1              237 мм
#
#      Габариты (длина × ширина × высота) Колёсная база Объём багажника  \
# 1698                 4950 × 2008 × 1776       2984 мм           721 л
# 1699                 4950 × 2008 × 1776       2984 мм           692 л
# 1700                 4950 × 2008 × 1776       2984 мм           692 л
# 1701                 4950 × 2008 × 1776       2984 мм           640 л
# 1702                 4950 × 2008 × 1776       2984 мм           640 л
#
#      Объём багажника максимальный Объём топливного бака Масса автомобиля
# 1698                       1899 л                  71 л          1969 кг
# 1699                       1899 л                  71 л          2004 кг
# 1700                       1899 л                  71 л          2009 кг
# 1701                       1899 л                  70 л          2350 кг
# 1702                       1899 л                  70 л          2350 кг
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1703 entries, 0 to 1702
# Data columns (total 21 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   brand                                                 1703 non-null   object
#  1   model                                                 1703 non-null   object
#  2   complect                                              1703 non-null   object
#  3   type_car                                              1703 non-null   object
#  4   seats                                                 1703 non-null   int64
#  5   doors                                                 1703 non-null   int64
#  6   Двигатель                                             1703 non-null   object
#  7   Мощность                                              1703 non-null   object
#  8   Крутящий момент двигателя                             1703 non-null   object
#  9   Коробка передач                                       1703 non-null   object
#  10  Привод                                                1703 non-null   object
#  11  Разгон до сотни                                       1703 non-null   object
#  12  Максимальная скорость                                 1703 non-null   object
#  13  Расход топлива (л/100 км)
# город / трасса / смешанный  1703 non-null   object
#  14  Дорожный просвет                                      1703 non-null   object
#  15  Габариты (длина × ширина × высота)                    1703 non-null   object
#  16  Колёсная база                                         1703 non-null   object
#  17  Объём багажника                                       1703 non-null   object
#  18  Объём багажника максимальный                          1703 non-null   object
#  19  Объём топливного бака                                 1703 non-null   object
#  20  Масса автомобиля                                      1703 non-null   object
# dtypes: int64(2), object(19)
# memory usage: 279.5+ KB

# %%
df.describe()
# Out:
#              seats        doors
# count  1703.000000  1703.000000
# mean      5.079272     4.887845
# std       0.677096     1.024259
# min       1.000000     2.000000
# 25%       5.000000     4.000000
# 50%       5.000000     5.000000
# 75%       5.000000     5.000000
# max       9.000000     8.000000

# %% [markdown]
# После этого шага понял, что нужно будет преобразовывать все записи в столбцах нужно будет преобразовать из категориальных значений переменных в числовые для дальнейшей работы с ними (тип object не будет работать в knn и random forest classifier). Также проверил данные в столбце "type_car" (количество уникальных значений, т.к. это будет целевая переменная, на предсказание которой будем настраивать модели в дальнейшем). В ячейке ниже проверял также все уникальные значения для всех столбцов. Позже заметил, что в столбце "Разгон до сотни" есть 71 значение "нет данных".

# %%
columns = df.columns
for column in columns:
    #print(column)
    #print(df[column].unique())
    print(column)
    print((df[column] == "нет данных").sum())
# Out:
# brand
# 0
# model
# 0
# complect
# 0
# type_car
# 0
# seats
# 0
# doors
# 0
# Двигатель
# 0
# Мощность
# 0
# Крутящий момент двигателя
# 0
# Коробка передач
# 0
# Привод
# 0
# Разгон до сотни
# 71
# Максимальная скорость
# 0
# Расход топлива (л/100 км)
# город / трасса / смешанный
# 0
# Дорожный просвет
# 0
# Габариты (длина × ширина × высота)
# 0
# Колёсная база
# 0
# Объём багажника
# 0
# Объём багажника максимальный
# 0
# Объём топливного бака
# 0
# Масса автомобиля
# 0

# %% [markdown]
# Дальше решил посмотреть, есть ли отсутствующие данные в других столбцах. На вскидку, есть нулевые значения в следующих столбцах: "Разгон до сотни", "Максимальная скорость", "Расход топлива", "Объем багажника" и "Объем багажника максимальный".
# В дальнейшем есть 2 варианта решения данной проблемы:
# 1. Найти все данные из открытых источников (спецификация модели с оффициальных сайтов).
# 2. Убрать данные строки из датасета, чтобы не произошло перекоса по предсказаниям данных классов.

# %%
no_data = df[df["Разгон до сотни"] == "нет данных"]
for column in columns:
    print(column)
    print(no_data[column].unique())
# Out:
# brand
# ['Genesis' 'Jeep' 'Lexus' 'Mitsubishi' 'Suzuki' 'Toyota' 'Volkswagen']
# model
# ['G80' 'Compass' 'Wrangler 2D' 'Wrangler 4D' 'NX' 'L200' 'Jimny'
#  'Fortuner' 'Hiace' 'Highlander' 'Hilux' 'Land Cruiser Prado' 'Multivan'
#  'Passat']
# complect
# ['Business 2.0L T-GDI 8AT 4WD 197 hp' 'Advance 2.0L T-GDI 8AT 4WD 197 hp'
#  'Premium 2.0L T-GDI 8AT 4WD 197 hp' 'Longitude' 'Limited' 'Trailhawk'
#  '2.0 AT8 Sport' '2.0 AT8 Sahara' '2.0 AT8 Rubicon' '200 Standart'
#  'Invite' 'Invite+' 'Intense' 'Intense AT' 'Instyle AT' 'GL MT' 'GL AT'
#  'GLX AT' 'Elegance 2.8D 6AT' 'Prestige 2.8D 6AT' '3.0D MT Standart'
#  '3.0D AT Elegance' '3.0D AT Prestige Safety' '3.5 Prestige'
#  '3.5 Luxe Safety' 'Standart 2.7 MT' 'Standart 2.4 MT' 'Comfort 2.4 MT'
#  '2.8 AT Comfort' '2.8 AT Elegance' '2.8 AT Elegance Plus'
#  '2.8 AT Prestige' '2.8 AT Black Onyx 5-seater'
#  '2.8 AT Black Onyx 7-seater' 'Trendline 2.0 TDI 102 hp 5MT'
#  'Trendline 2.0 TSI 150 hp 6MT' 'Trendline 2.0 TDI 140 hp 6MT'
#  'Trendline 2.0 TDI 140 hp 7AMT' 'Comfortline 2.0 TSI 150 hp 6MT'
#  'Trendline 2.0 TDI 150 hp 7AMT 4Motion' 'Comfortline 2.0 TDI 102 hp 5MT'
#  'Comfortline 2.0 TDI 140 hp 6MT' 'Trendline 2.0 TDI 150 hp 7AMT'
#  'Comfortline 2.0 TDI 140 hp 7AMT' 'Highline 2.0 TSI 150 hp 6MT'
#  'Comfortline 2.0 TDI 150 hp 7AMT' 'Highline 2.0 TDI 140 hp 6MT'
#  'Comfortline 2.0 biTDI 180 hp 7AMT'
#  'Comfortline 2.0 TDI 150 hp 7AMT 4Motion' 'Highline 2.0 TDI 140 hp 7AMT'
#  'Comfortline 2.0 TSI 204 hp 7AMT'
#  'Comfortline 2.0 biTDI 180 7AMT 4Motion' 'Highline 2.0 TDI 150 hp 7AMT'
#  'Comfortline 2.0 biTDI 204 hp 7AMT'
#  'Comfortline 2.0 TSI 204 hp 7AMT 4Motion'
#  'Highline 2.0 biTDI 180 hp 7AMT'
#  'Comfortline 2.0 biTDI 204 hp 7AMT 4Motion'
#  'Highline 2.0 TDI 150 hp 7AMT 4Motion' 'Highline 2.0 TSI 204 hp 7AMT'
#  'Highline 2.0 biTDI 180 7AMT 4Motion' 'Highline 2.0 biTDI 204 hp 7AMT'
#  'Highline 2.0 TSI 204 hp 7AMT 4Motion'
#  'Highline 2.0 biTDI 204 hp 7AMT 4Motion' 'Respect 1.4 6MT'
#  'Business 1.4 7AMT' 'Business 2.0 7AMT' 'Exclusive 1.4 7AMT'
#  'Exclusive 2.0 7AMT']
# type_car
# ['Седан класса E' 'Компактный кроссовер' 'Внедорожник класса B'
#  'Среднеразмерный внедорожник' 'Пикап' 'Вэн' 'Большой кроссовер'
#  'Большой внедорожник' 'Седан класса D']
# seats
# [5 4 7 1 9]
# doors
# [4 5 2 3 7]
# Двигатель
# ['бензиновый (1998 см³)' 'бензиновый (2360 см³)' 'бензиновый (1995 см³)'
#  'бензиновый (1986 см³)' 'дизельный (2442 см³)' 'бензиновый (1462 см³)'
#  'дизельный (2755 см³)' 'бензиновый (3456 см³)' 'бензиновый (2694 см³)'
#  'дизельный (2393 см³)' 'дизельный (1968 см³)' 'бензиновый (1984 см³)'
#  'бензиновый (1395 см³)']
# Мощность
# ['197 л. с.' '150 л. с.' '175 л. с.' '272 л. с.' '154 л. с.' '181 л. с.'
#  '102 л. с.' '200 л. с.' '249 л. с.' '166 л. с.' '140 л. с.' '180 л. с.'
#  '204 л. с.' '190 л. с.']
# Крутящий момент двигателя
# ['353 Н·м' '229 Н·м' '237 Н·м' '400 Н·м' '189 Н·м' '380 Н·м' '430 Н·м'
#  '130 Н·м' '500 Н·м' '420 Н·м' '356 Н·м' '245 Н·м' '250 Н·м' '280 Н·м'
#  '340 Н·м' '350 Н·м' '450 Н·м' '320 Н·м']
# Коробка передач
# ['автоматическая (8 ступеней)' 'автоматическая (9 ступеней)'
#  'вариатор (0 ступеней)' 'механическая (6 ступеней)'
#  'автоматическая (6 ступеней)' 'механическая (5 ступеней)'
#  'автоматическая (4 ступеней)' 'роботизированная (7 ступеней)']
# Привод
# ['полный' 'передний' 'задний']
# Разгон до сотни
# ['нет данных']
# Максимальная скорость
# ['237 км/ч' '0 км/ч' '180 км/ч' '169 км/ч' '173 км/ч' '171 км/ч'
#  '177 км/ч' '145 км/ч' '140 км/ч' '150 км/ч' '170 км/ч' '175 км/ч'
#  '157 км/ч' '172 км/ч' '178 км/ч' '181 км/ч' '191 км/ч' '202 км/ч'
#  '188 км/ч' '203 км/ч' '198 км/ч' '199 км/ч' '220 км/ч' '232 км/ч']
# Расход топлива (л/100 км)
# город / трасса / смешанный
# ['12.2 / 7.5 / 9.2' '13.8 / 7.2 / 9.6' '13.9 / 7.6 / 9.9' '0 / 0 / 0'
#  '8.8 / 6 / 7.2' '9 / 7 / 7.7' '9.9 / 7.8 / 8.6' '7.7 / 6.2 / 6.8'
#  '8.4 / 6.9 / 7.5' '8.9 / 6.4 / 7.3' '9.5 / 6.7 / 7.7' '9.5 / 6.1 / 7.3'
#  '12.8 / 7.8 / 9.6' '9.6 / 6.7 / 8' '10.2 / 6.7 / 8' '7.1 / 6 / 6.4'
#  '6.8 / 5.6 / 6.1' '10 / 6.7 / 7.9' '13.5 / 8.1 / 10.1' '11.1 / 7.5 / 8.8'
#  '8 / 5.8 / 6.6' '14 / 8.5 / 10.5' '8.1 / 6.1 / 6.8' '6.3 / 4.5 / 5.1'
#  '7.1 / 5 / 5.8']
# Дорожный просвет
# ['150 мм' '208 мм' '216 мм' '246 мм' '185 мм' '200 мм' '220 мм' '210 мм'
#  '225 мм' '175 мм' '204 мм' '227 мм' '215 мм' '193 мм' '160 мм']
# Габариты (длина × ширина × высота)
# ['4990 × 1890 × 1480' '4394 × 2033 × 1644' '4394 × 2033 × 1660'
#  '4334 × 1894 × 1858' '4334 × 1894 × 1878' '4334 × 1894 × 1879'
#  '4882 × 1894 × 1881' '4882 × 1894 × 1891' '4882 × 1894 × 1901'
#  '4640 × 1845 × 1645' '5225 × 1815 × 1775' '5225 × 1815 × 1795'
#  '3650 × 1645 × 1725' '4795 × 1855 × 1835' '5915 × 1950 × 2280'
#  '5300 × 1970 × 1990' '4966 × 1930 × 1755' '5325 × 1855 × 1815'
#  '4840 × 1855 × 1845' '4904 × 1904 × 1970' '4775 × 1832 × 1483']
# Колёсная база
# ['3010 мм' '2636 мм' '2459 мм' '3008 мм' '2660 мм' '3000 мм' '2250 мм'
#  '2745 мм' '3860 мм' '3210 мм' '2890 мм' '2790 мм' '3085 мм' '2786 мм']
# Объём багажника
# ['493 л' '368 л' '142 л' '553 л' '500 л' '0 л' '85 л' '297 л' '454 л'
#  '621 л' '104 л' '586 л']
# Объём багажника максимальный
# ['493 л' '1693 л' '430 л' '1044 л' '1600 л' '0 л' '830 л' '620 л' '1935 л'
#  '1909 л' '1934 л' '1833 л' '5800 л' '1152 л']
# Объём топливного бака
# ['77 л' '60 л' '66 л' '81 л' '75 л' '40 л' '87 л' '70 л' '68 л' '80 л']
# Масса автомобиля
# ['2015 кг' '1542 кг' '1552 кг' '1644 кг' '1819 кг' '1960 кг' '1625 кг'
#  '1930 кг' '1090 кг' '1110 кг' '2175 кг' '2195 кг' '2125 кг' '2100 кг'
#  '2110 кг' '1950 кг' '2130 кг' '2235 кг' '1976 кг' '2007 кг' '1980 кг'
#  '2005 кг' '2180 кг' '2047 кг' '2124 кг' '2053 кг' '2228 кг' '2162 кг'
#  '2163 кг' '2265 кг' '1413 кг' '1480 кг']

# %% [markdown]
# ### Фильтрация данных
#
# В большинстве столбцов данные представлены в виде типа object, поэтому их нужно преобразовать в тип int или float.
# прообразовывал столбцы с помощью regex, lambda-функций и функции map.

# %%
df['Мощность'] = df['Мощность'].str.extract('(\d+)').astype(int)
df['Двигатель'] = df['Двигатель'].str.extract('(\w+)')
df['Разгон до сотни'] = df['Разгон до сотни'].str.extract('(\d+)').astype(float)
df['Крутящий момент двигателя'] = df['Крутящий момент двигателя'].str.extract('(\d+)').astype(int)
df['Дорожный просвет'] = df['Дорожный просвет'].str.extract('(\d+)').astype(int)
df['Максимальная скорость'] = df['Максимальная скорость'].str.extract('(\d+)').astype(int)
df['Колёсная база'] = df['Колёсная база'].str.extract('(\d+)').astype(int)
df['Объём багажника'] = df['Объём багажника'].str.extract('(\d+)').astype(int)
df['Объём багажника максимальный'] = df['Объём багажника максимальный'].str.extract('(\d+)').astype(int)
df['Объём топливного бака'] = df['Объём топливного бака'].str.extract('(\d+)').astype(int)
df['Масса автомобиля'] = df['Масса автомобиля'].str.extract('(\d+)').astype(int)
df['type_car'] = df['type_car'].str.lower()

# %%
df[['город', 'трасса', 'смешанный']] = df['Расход топлива (л/100 км)\nгород / трасса / смешанный'].\
str.split(" / ",expand=True).astype(float)
df[['длина', 'ширина', 'высота']] = df['Габариты (длина × ширина × высота)'].str.split(" × ",expand=True).astype(int)

# %%
privod = {'полный': 1, 'передний': 2, 'задний': 3}
engine = {'бензиновый': 1, 'дизельный': 2, 'электрический': 3, 'гибридный': 4}
car = {}

# %%
df['Двигатель'].unique()
# Out:
# array(['бензиновый', 'дизельный', 'электрический', 'гибридный'],
#       dtype=object)

# %%
df['Привод'] = df['Привод'].map(privod)
df['Двигатель'] = df['Двигатель'].map(engine)

# %% [markdown]
# Создаем лист с уникальными значениями типа кузова из датасета и смотрим их кол-во.

# %%
types = df['type_car'].unique().tolist()

sns.set(rc={'figure.figsize':(15,15)});
sns.histplot(df['type_car'].value_counts(), x=df["type_car"] );
plt.xticks(rotation=90);

# %% [markdown]
# Далее меняем вид кузова на тип без подкласса (пикап добавил к внедорожнику; купе, родстер и кабриолет добавил к классу купе). Возможно, этого делать не нужно было, но тогда в этих небольших классах остается 30-50 записей данных, из-за чего не получается нормально выделить кластера в сравнении с остальными (в классе кроссовер 754 записи).

# %%
car_types = dict()
'''for car_type in df['type_car'].unique():
    if 'седан' in car_type:
        car_types[car_type] = 'седан'
    elif 'хэтчбек' in car_type:
        car_types[car_type] = 'хэтчбек'
    elif 'универсал' in car_type:
        car_types[car_type] = 'универсал'
    elif 'купе' in car_type:
        car_types[car_type] = 'купе'
    elif 'кроссовер' in car_type:
        car_types[car_type] = 'кроссовер'
    elif 'внедорожник' in car_type:
        car_types[car_type] = 'внедорожник'
    elif 'вэн' in car_type:
        car_types[car_type] = 'вэн'
    elif 'родстер' in car_type:
        car_types[car_type] = 'родстер'
    elif 'пикап' in car_type:
        car_types[car_type] = 'пикап'
    elif 'кабриолет' in car_type:
        car_types[car_type] = 'кабриолет' '''


for car_type in df['type_car'].unique():
    if 'седан' in car_type:
        car_types[car_type] = 'седан'
    elif 'кроссовер' in car_type:
        car_types[car_type] = 'кроссовер'
    elif 'хэтчбек' in car_type:
        car_types[car_type] = 'хэтчбек'
    elif 'универсал' in car_type:
        car_types[car_type] = 'универсал'
    elif 'вэн' in car_type:
        car_types[car_type] = 'вэн'
    elif ('внедорожник' or 'пикап') in car_type:
        car_types[car_type] = 'внедорожник'
    elif 'купе' or 'родстер' or 'кабриолет' in car_type:
        car_types[car_type] = 'купе'

# %%
df['type_car'] = df['type_car'].map(car_types)
df['type_car'].unique()
# Out:
# array(['седан', 'хэтчбек', 'универсал', 'купе', 'кроссовер',
#        'внедорожник', 'вэн'], dtype=object)

# %% [markdown]
# Проверяем выборку на сбалансированность.

# %%
sns.set(rc={'figure.figsize':(10,10)});
sns.histplot(df['type_car'].value_counts(), x=df["type_car"] );
plt.xticks(rotation=45);

# %% [markdown]
# Видим, что выборка получается очень несбалансированной. Есть 2 возможных варианта: сделать все классы одного размера с уменьшением или сделать все классы одного размера с увеличением малых классов. Я выбрал второй вариант.

# %%
df_1 = df[df['type_car'] == 'хэтчбек']
df_2 = df[df['type_car'] == 'универсал']
df_3 = df[df['type_car'] == 'купе']
df_4 = df[df['type_car'] == 'внедорожник']
df_5 = df[df['type_car'] == 'вэн']
    
df = df.append([df_1]*2,ignore_index=True)
df = df.append([df_2]*5,ignore_index=True)
df = df.append([df_3]*4,ignore_index=True)
df = df.append([df_4]*2,ignore_index=True)
df = df.append([df_5]*4,ignore_index=True)

# %%
sns.set(rc={'figure.figsize':(10,10)});
sns.histplot(df['type_car'].value_counts(), x=df["type_car"] );
plt.xticks(rotation=45);

# %% [markdown]
# Проверяем как коррелируют атрибуты между собой.

# %%
sns.set(rc={'figure.figsize':(20,15)});
sns.heatmap(df.corr(), cmap="YlGnBu", annot=True);

# %%
sns.boxplot(x="type_car", y="Дорожный просвет", data=df);

# %%
sns.boxplot(x="type_car", y="Объём багажника максимальный", data=df);

# %%
sns.boxplot(x="type_car", y="Максимальная скорость", data=df);

# %% [markdown]
# На боксплотах выше видно, что в данных есть вылеты (0, хотя здесь nan) по некоторым столбцам. Например, 0 мм дорожный просвет быть не может, как и максимальная скорость, поэтому здесь удаляем данные значения. Далее еще раз смотрим на конечный результат преобразований.

# %%
#df['Дорожный просвет'][(df['type_car'] == 'внедорожник') & (df['Дорожный просвет'] != 0)].median()
#df['Дорожный просвет'][(df['type_car'] == 'кроссовер') & (df['Дорожный просвет'] != 0)].median()

# %%
df.fillna(0, inplace=True)
#for column in columns:
    #df = df[(df[column] != 0)]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3285 entries, 0 to 3284
# Data columns (total 27 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   brand                                                 3285 non-null   object
#  1   model                                                 3285 non-null   object
#  2   complect                                              3285 non-null   object
#  3   type_car                                              3285 non-null   object
#  4   seats                                                 3285 non-null   int64
#  5   doors                                                 3285 non-null   int64
#  6   Двигатель                                             3285 non-null   int64
#  7   Мощность                                              3285 non-null   int32
#  8   Крутящий момент двигателя                             3285 non-null   int32
#  9   Коробка передач                                       3285 non-null   object
#  10  Привод                                                3285 non-null   int64
#  11  Разгон до сотни                                       3285 non-null   float64
#  12  Максимальная скорость                                 3285 non-null   int32
#  13  Расход топлива (л/100 км)
# город / трасса / смешанный  3285 non-null   object
#  14  Дорожный просвет                                      3285 non-null   int32
#  15  Габариты (длина × ширина × высота)                    3285 non-null   object
#  16  Колёсная база                                         3285 non-null   int32
#  17  Объём багажника                                       3285 non-null   int32
#  18  Объём багажника максимальный                          3285 non-null   int32
#  19  Объём топливного бака                                 3285 non-null   int32
#  20  Масса автомобиля                                      3285 non-null   int32
#  21  город                                                 3285 non-null   float64
#  22  трасса                                                3285 non-null   float64
#  23  смешанный                                             3285 non-null   float64
#  24  длина                                                 3285 non-null   int32
#  25  ширина                                                3285 non-null   int32
#  26  высота                                                3285 non-null   int32
# dtypes: float64(4), int32(12), int64(4), object(7)
# memory usage: 539.1+ KB

# %% [markdown]
# Создаем матрицу с независимыми переменными Х и вектор-ответ у. Также делим выборку на ренировочную и тестовую. Сравниваем размерности выборок.

# %%
y = df['type_car']
X = df.drop(['type_car', 'brand', 'model', 'complect', 'Коробка передач', 'Расход топлива (л/100 км)\n\
город / трасса / смешанный', 'Габариты (длина × ширина × высота)'],axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=4)
X_train.shape, X_test.shape
# Out:
# ((2200, 20), (1085, 20))

# %%
sns.histplot(df['type_car'].value_counts(), x=df["type_car"] );
plt.xticks(rotation=45);

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2200 entries, 3023 to 1146
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   seats                         2200 non-null   int64
#  1   doors                         2200 non-null   int64
#  2   Двигатель                     2200 non-null   int64
#  3   Мощность                      2200 non-null   int32
#  4   Крутящий момент двигателя     2200 non-null   int32
#  5   Привод                        2200 non-null   int64
#  6   Разгон до сотни               2200 non-null   float64
#  7   Максимальная скорость         2200 non-null   int32
#  8   Дорожный просвет              2200 non-null   int32
#  9   Колёсная база                 2200 non-null   int32
#  10  Объём багажника               2200 non-null   int32
#  11  Объём багажника максимальный  2200 non-null   int32
#  12  Объём топливного бака         2200 non-null   int32
#  13  Масса автомобиля              2200 non-null   int32
#  14  город                         2200 non-null   float64
#  15  трасса                        2200 non-null   float64
#  16  смешанный                     2200 non-null   float64
#  17  длина                         2200 non-null   int32
#  18  ширина                        2200 non-null   int32
#  19  высота                        2200 non-null   int32
# dtypes: float64(4), int32(12), int64(4)
# memory usage: 257.8 KB

# %% [markdown]
# ### 4. Классификация автомобилей по типу кузовов
#
# Попробовал 2 модели: Random Forest Classifier и K Near Neighbours.

# %%
clf = RandomForestClassifier(random_state=4)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=4)

# %%
scores = cross_val_score(clf, X_train, y_train, cv=5)
scores.mean()
# Out:
# 0.9977272727272727

# %% [markdown]
# Создаем простую функцию для K-fold cross validation для random forest

# %%
def mean_score_rf(X, y):
    
    score_mean = list()
    kfold = KFold(n_splits=5)
    
    for train, test in kfold.split(X):
        #print(train, test)
        X_train, X_test = X.iloc[train], X.iloc[test]
        y_train, y_test = y.iloc[train], y.iloc[test]
        clf.fit(X_train, y_train)
        score_mean.append(clf.score(X_test, y_test))
        
    return np.mean(score_mean)

mean_score_rf(X_train, y_train)
# Out:
# 0.9977272727272727

# %%
clf.score(X_test, y_test)
# Out:
# 0.9990783410138249

# %%
y_pred_rf = clf.predict(X_test)

# %% [markdown]
# #### Пробуем алгоритм К ближайших соседей
#
# Количество кластеров должно быть равно количеству классов (в идеале)

# %%
neigh = KNeighborsClassifier(n_neighbors=6)
neigh.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %%
def mean_score_knn(X, y):
    
    score_mean = list()
    kfold = KFold(n_splits=5)
    
    for train, test in kfold.split(X):
        #print(train, test)
        X_train, X_test = X.iloc[train], X.iloc[test]
        y_train, y_test = y.iloc[train], y.iloc[test]
        neigh.fit(X_train, y_train)
        score_mean.append(neigh.score(X_test, y_test))
        
    return np.mean(score_mean)

mean_score_knn(X_train, y_train)
# Out:
# 0.9672727272727272

# %%
scores = cross_val_score(neigh, X_train, y_train, cv=5)
scores.mean()
# Out:
# 0.9681818181818181

# %%
neigh.score(X_test, y_test)
# Out:
# 0.9585253456221198

# %%
y_pred_knn = neigh.predict(X_test)

# %% [markdown]
# Меняем количество кластеров

# %%
k_range = range(1, 31)


k_scores = []


for k in k_range:
    
    knn = KNeighborsClassifier(n_neighbors=k)
    
    scores = cross_val_score(knn, X_train, y_train, cv=10, scoring='accuracy')
    
    k_scores.append(scores.mean())
print(k_scores)
# Out:
# [0.9931818181818182, 0.9886363636363636, 0.9831818181818182, 0.9777272727272728, 0.975, 0.9722727272727273, 0.9650000000000001, 0.955909090909091, 0.9472727272727273, 0.9359090909090908, 0.9199999999999999, 0.9118181818181819, 0.9036363636363636, 0.9018181818181817, 0.8931818181818183, 0.8931818181818182, 0.8886363636363637, 0.8836363636363636, 0.8781818181818182, 0.8740909090909093, 0.8695454545454545, 0.8668181818181818, 0.8636363636363636, 0.8622727272727273, 0.8581818181818182, 0.8581818181818182, 0.8559090909090908, 0.850909090909091, 0.8477272727272729, 0.8445454545454545]

# %%
plt.plot(k_range, k_scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Cross-Validated Accuracy');

# %% [markdown]
# #### Пробуем XGboost
#
# С XGBoost никогда до этого не работал, поэтому беру все "из коробки".

# %%
xgboost = XGBClassifier()
xgboost.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [01:22:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=12, num_parallel_tree=1,
#               objective='multi:softprob', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
def mean_score_xgboost(X, y):
    
    score_mean = list()
    kfold = KFold(n_splits=5)
    
    for train, test in kfold.split(X):
        #print(train, test)
        X_train, X_test = X.iloc[train], X.iloc[test]
        y_train, y_test = y.iloc[train], y.iloc[test]
        xgboost.fit(X_train, y_train)
        score_mean.append(xgboost.score(X_test, y_test))
        
    return np.mean(score_mean)

mean_score_xgboost(X_train, y_train)
# Out:
# [01:22:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [01:22:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [01:22:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [01:22:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [01:22:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9981818181818181

# %%
scores = cross_val_score(xgboost, X_train, y_train, cv=5)
scores.mean()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [01:22:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [01:22:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [01:22:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [01:22:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [01:22:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9981818181818181

# %%
xgboost.score(X_test, y_test)
# Out:
# 0.9981566820276497

# %%
y_pred_xgboost = xgboost.predict(X_test)

# %% [markdown]
# На кросс-валидации XGBoost показал большую точность, поэтому я бы в первую очередь попробовал его на новых данных, потом случайный лес, и после уже К ближайших соседей.

# %%
df_new_7 = X_test
df_new_7['Ground truth'] = y_test
df_new_7['Random Forest prediction'] = y_pred_rf
df_new_7['KNN prediction'] = y_pred_knn
df_new_7['XGBoost prediction'] = y_pred_xgboost
# Out:
# <ipython-input-46-36050e17f971>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new_7['Ground truth'] = y_test
# <ipython-input-46-36050e17f971>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new_7['Random Forest prediction'] = y_pred_rf
# <ipython-input-46-36050e17f971>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new_7['KNN prediction'] = y_pred_knn
# <ipython-input-46-36050e17f971>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new_7['XGBoost prediction'] = y_pred_xgboost

# %%
df_new_7.head()
# Out:
#       seats  doors  Двигатель  Мощность  Крутящий момент двигателя  Привод  \
# 1387      5      5          1       150                        196       1
# 1209      7      5          2       150                        370       2
# 2390      5      4          2       180                        400       1
# 1903      5      5          1       123                        151       2
# 2882      5      5          1       309                        439       1
#
#       Разгон до сотни  Максимальная скорость  Дорожный просвет  Колёсная база  \
# 1387             10.0                    192               220           2665
# 1209             12.0                    183               175           3275
# 2390             11.0                    174               192           3097
# 1903             11.0                    183               195           2600
# 2882              8.0                    195               230           2850
#
#       ...  город  трасса  смешанный  длина  ширина  высота  Ground truth  \
# 1387  ...    9.0     5.9        7.1   4465    1800    1615     кроссовер
# 1209  ...    7.3     5.8        6.4   5308    1920    1940           вэн
# 2390  ...    9.4     6.7        7.6   5254    1954    1834          купе
# 1903  ...    8.9     5.6        6.8   4240    1750    1510       хэтчбек
# 2882  ...   18.2    11.4       13.9   4950    1980    1955   внедорожник
#
#       Random Forest prediction  KNN prediction  XGBoost prediction
# 1387                 кроссовер       кроссовер           кроссовер
# 1209                       вэн             вэн                 вэн
# 2390                      купе            купе                купе
# 1903                   хэтчбек         хэтчбек             хэтчбек
# 2882               внедорожник     внедорожник         внедорожник
#
# [5 rows x 24 columns]

# %%
df_new_7.to_excel("Manual observation of results 7 types.xlsx")

# %%
df_new_10 = pd.DataFrame()
df_new_10['Ground truth'] = y_test
df_new_10['Random Forest prediction'] = y_pred_rf
df_new_10['KNN prediction'] = y_pred_knn
df_new_10['XGBoost prediction'] = y_pred_xgboost

# %%
types = df_new_10["Ground truth"].unique()

print(types, '\n'
    "Ground truth  ", df_new_10['Ground truth'].value_counts().unique(),'\n',\
      "Random forest", df_new_10['Random Forest prediction'].value_counts().unique(),'\n',\
       "KNN          ", df_new_10['KNN prediction'].value_counts().unique(), '\n',\
      "XGBoost      ", df_new_10['XGBoost prediction'].value_counts().unique())
# Out:
# ['кроссовер' 'вэн' 'купе' 'хэтчбек' 'внедорожник' 'универсал' 'седан']
# Ground truth   [272 162 149 145 128 117 112]
#  Random forest [271 162 150 145 128 117 112]
#  KNN           [256 163 157 146 130 122 111]
#  XGBoost       [270 162 149 145 129 118 112]
